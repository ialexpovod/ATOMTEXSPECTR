# %%
from ATOMTEXSPECTR import spectr, plotting, read
import matplotlib.pyplot

# %%
s_1 = spectr.Spectr.import_file(r'/Users/ialexpovod/PycharmProjects/ATOMTEXSPECTR/tests/spectrum/BDKG11M_sample.spe')
# Out:
# Filename file-spectrum:/Users/ialexpovod/PycharmProjects/ATOMTEXSPECTR/tests/spectrum/BDKG11M_sample.spe

# %%
print(s_1)
# Out:
# ATOMTEXSPECTR.Spectr
#     point_start:                             None
#     point_stop:                              None
#     actualtime:                              829.0
#     measuretime:                             827.0
#     is_calibrated:                           False
#     Каналов:                                 1024
#     Общее количество отсчетов:               (5.213+/-0.023)e+04
#     Суммареая скорость счета:                63.04+/-0.28
#     filename:                                /Users/ialexpovod/PycharmProjects/ATOMTEXSPECTR/tests/spectrum/BDKG11M_sample.spe

# %%
s_1.plot()
matplotlib.pyplot.show()
